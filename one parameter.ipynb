# %%
import numpy as np
import pandas as pd
import astropy.units as u
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import normalize
import os
from PIL import Image
import glob
import subprocess
import matplotlib as mpl
import gc
import matplotlib
import seaborn as sns
from sklearn.metrics import mean_squared_error
import emcee


os.makedirs("frames", exist_ok=True)

# ---- fibonacci sphere ----
def fibonacci_sphere(n_points):
    """generating equal points to distributing in sphere"""
    indices = np.arange(n_points, dtype=float) + 0.5
    phi = np.arccos(1 - 2*indices/n_points)  # [0, π]
    theta = np.pi * (1 + 5**0.5) * indices  # aureo angle
    
    return phi, theta % (2*np.pi)  # etting values between 0 and 2π

def cartesian_from_spherical(phi, theta, r=1.0):
    """Convert spherical coordinates to cartesians"""
    x = r * np.sin(phi) * np.cos(theta)
    y = r * np.sin(phi) * np.sin(theta)
    z = r * np.cos(phi)
    return x, y, z

def spot_mask_geodesic(x, y, z, spot_center, spot_radius_rad):
    """Máscara usando distancia geodésica real con optimización"""
    # Convert the spot_center vector to a unit vector (of length 1).
    center_norm = spot_center / np.linalg.norm(spot_center)
    
    # Product
    positions = np.stack([x, y, z], axis=-1)
    norms = np.linalg.norm(positions, axis=-1, keepdims=True)
    pos_norm = positions / np.clip(norms, 1e-10, None)     
    dot_product = np.sum(pos_norm * center_norm, axis=-1) 
    dot_product = np.clip(dot_product, -1, 1) 
    
    # central_angle is the geodesic distance (in radians) betwe.
    central_angle = np.arccos(dot_product)
    
    return np.exp(-(central_angle**2) / (2 * spot_radius_rad**2))

#function to calculate angular velocity  
def spot_theta(rotation_period, spot_colatitude, relative_shear):
    ''' Parameters:
    - rotation_period: rotation period of the sta
    - spot_colatitude: latitud of spot(radians)
    - relative_shear: parameter between pole and equator
    Returns:
    - angular velocity. '''
    
    latitude = np.pi / 2 - spot_colatitude
    angular_vel_equa = 2*np.pi*u.rad/rotation_period
    angular_velocity = angular_vel_equa*(1-relative_shear*np.sin(latitude)**2)
    return angular_velocity

def limbdarkening(u, mu):
    ''' lineal limb darkening'''
    return (1 - u * (1 - mu))

def quadratic(u1, u2, mu):
    return 1-u1*(1-mu)-u2*(1-mu)**2
    

def add_spots(latitude_deg, longitude_deg, radii_deg):
    colatitude_rad = np.deg2rad(90 - latitude_deg)
    longitude_rad = np.deg2rad(longitude_deg)
    radii_rad = np.deg2rad(radii_deg)
    ang_vel = spot_theta(rotation_period, colatitude_rad, 0.4)  
    spots.append({
        'theta': longitude_rad * u.rad,
        'phi': colatitude_rad,
        'radius': radii_rad,
        'angular_velocity': ang_vel
    })
    #return spots
def gif(input_pattern="frames/frame_%05d.png", output_gif="output.gif", 
        palette="palette.png", framerate=17):
    palette_cmd = [
        "ffmpeg", "-y", "-i", input_pattern,
        "-vf", "palettegen", palette
    ]
    gif_cmd = [
        "ffmpeg", "-y", "-framerate", str(framerate),
        "-i", input_pattern, "-i", palette,
        "-lavfi", "paletteuse", output_gif
    ]
    try:
        subprocess.run(palette_cmd, check=True)
        subprocess.run(gif_cmd, check=True)
        print(f"GIF creado: {output_gif}")
    except subprocess.CalledProcessError as e:
        print("Error en ffmpeg:", e)

def flux_plot(theta_vec):
    '''
    Function take a list normalizing the flux, converting the list in a 
csv file and rename the columns
    and return a plot 

    '''
    #lat,lon,radii = theta_vec
    radii = theta_vec[0]
    frame_files = sorted(glob.glob("frames/frame_*.png"))
    fluxes = []

    for filename in frame_files:
        img = Image.open(filename).convert('L')  # Grayscale
        img_array = np.array(img, dtype=np.float64)
        flux_total = np.sum(img_array)
        fluxes.append(flux_total)

    # Normalized fluxes
    #flux_norm.append(flux_total / fluxes[i])
    flux_norm = normalize([fluxes], norm="max")[0]
    #flux_norm = np.array(fluxes)/np.max(np.array(fluxes))
    df = pd.DataFrame(flux_norm)

    # Creating columns
    df.index.name = 'Frame'
    df.reset_index(inplace=True)
    #changing frames for days
    df['Days'] = df['Frame'] *(cadence_time.to(u.day)).value
    df = df.rename(columns={0: 'flux_normalized'})
    df = df[['Days', 'flux_normalized']]  

    # saving csv
    df.to_csv(f'lat_23_lon_0_radii{radii}.csv', index=False)
 
    
    #df.to_csv("test.csv", index=False)
    # plotting
    
    #ax = df.plot(x="Days", y="flux_normalized", alpha=0.5, linestyle='--', color ="k")
    #ax.set_xlabel("Time [days]")
    #ax.set_ylabel("Normalized Flux")
    #ax.set_title("Lightcurve from PNG frames")
    #plt.style.use('default')
    #plt.tight_layout()
    #plt.savefig(f'lat_{lat}_lon{lon}_radii{radii}.png', dpi=600)
    #plt.show()
    return df["flux_normalized"], df["Days"]

# ---- Función de animación corregida ----
def animate(i, points, base_intensity, ax_sphere, elev, azim, 
total_frames, vmin, vmax):
    ax_sphere.clear()
    ax_sphere.set_axis_off()
    ax_sphere.view_init(elev=elev, azim=azim)
    
    # copying the texture

    intensity = np.copy(base_intensity)
    
    # adding several spots
    for spot in spots:
        # Calcular nueva posición de la mancha
        theta_mov = spot['theta'] + spot['angular_velocity'] * i * cadence_time.to(u.day)
        
        # Calculating position of the spot
        spot_x = r_val * np.sin(spot['phi']) * np.cos(theta_mov.value)
        spot_y = r_val * np.sin(spot['phi']) * np.sin(theta_mov.value)
        spot_z = r_val * np.cos(spot['phi'])
        spot_center = np.array([spot_x, spot_y, spot_z])
        
        # creating a mask
        mask = spot_mask_geodesic(points[:, 0], points[:, 1], points[:, 2], spot_center, spot['radius'])
        intensity *= (1 -  mask)  # Reducción de intensidad en manchas
    
    # scatter plot 
    sc = ax_sphere.scatter(
        points[:, 0], points[:, 1], points[:, 2], 
        #c=intensity,
        c=np.clip(intensity, 0, 1),
        cmap='gray', 
        s=1, 
        alpha=1,
        vmin=0,  # Mínimo fijo
        vmax=1.0   # Máximo fijo
    )
    
    # Configurar límites de la esfera
    max_range = r_val * 1.1
    ax_sphere.set_xlim(-max_range, max_range)
    ax_sphere.set_ylim(-max_range, max_range)
    ax_sphere.set_zlim(-max_range, max_range)
    
    print(f"Procesando frame {i+1}/{total_frames}", end='\r')
    plt.savefig(f"frames/frame_{i:05d}.png", dpi=300, bbox_inches='tight')
    
    return None
 # Generating animation
def star_animate(theta_vec):
    
    #lat,lon,radii = theta_vec
    radii = theta_vec[0]
    add_spots(23, 0, radii)
        # spherical grid with fibonacci points
    print("Generate spherical grid")
    phi, theta = fibonacci_sphere(n_points)
    x, y, z = cartesian_from_spherical(phi, theta)
    points = np.vstack([x, y, z]).T
    
    # Calculate point of view
    elev_rad = np.deg2rad(elev) #elevation of point of view
    azim_rad = np.deg2rad(azim)#azimut of point of view
    
    v_x = np.cos(elev_rad) * np.cos(azim_rad)
    v_y = np.cos(elev_rad) * np.sin(azim_rad)
    v_z = np.sin(elev_rad)
    
    # rearrange of calculating mu parameter for limb darkening
    mu = (points[:, 0] * v_x + points[:, 1] * v_y + points[:, 2] * v_z) / r_val
    mu = np.clip(mu, 0, 1)
    #base_intensity = limbdarkening(constant, mu)# applying to the texture
    base_intensity = quadratic(u1,u2,mu) 
        #    Calculates the extreme values of the base intensity: 
    #vmin: Minimum value of intensity in the whole star.
    #vmax: Maximum value of intensity over the whole star.
    vmin=  0.0
    vmax=  1.0

   # Defines a reference range for color mapping that will be used consistently across all frames.
 
    
    # background configurations
    plt.style.use('dark_background')
    fig = plt.figure(figsize=(10, 8))
    ax_sphere = fig.add_subplot(111, projection='3d') 
    ax_sphere.set_axis_off()
    ax_sphere.set_box_aspect([1, 1, 1])
    
    #Límits
    max_range = r_val * 1.1
    ax_sphere.set_xlim(-max_range, max_range)
    ax_sphere.set_ylim(-max_range, max_range)
    ax_sphere.set_zlim(-max_range, max_range)

    print("start render...")
    for i in range(total_frames):
        animate(i, points, base_intensity, ax_sphere,  elev, azim, total_frames, vmin, vmax)
    # Create gif an light curve
    #print("\nCreando GIF...")
    #gif(input_pattern="frames/frame_%05d.png", output_gif=f"period_{rotation_period}_points{n_points}_obs{observing_baseline_days}_cadence{cadence_time}_nspots{len(spots)}.gif", framerate=15)
    print("Generating ligthcurve..")
    #to verify if is mcmc is working 
    #print(theta_vec)
    plt.style.use('default')
    spots.clear()
    plt.close(fig) 
    return flux_plot(theta_vec)

def load_tess():
# load tess light_curves
    csv1 = "test.csv"
    #csv2 = f"lat_{float(vec[0])}_lon{float(vec[1])}_radii{float(vec[2])}.csv"
    
    df1 = pd.read_csv(csv1)
    #df2 = pd.read_csv(csv2)
    F = df1["flux_normalized"]
    days =df1["Days"]
    return F, days 

#  verification function to find the aprox parameters value, recibing the test light curve and days
def function_mse(flux, days):
    #simulated folder
    sim_folder = 'light_curve'
    results = []
    #search csv, calculate MSE 
    for file in os.listdir(sim_folder):
        if file.endswith('.csv'):
            path = os.path.join(sim_folder, file)
            try:
                sim_curve = pd.read_csv(path)
                sim_flux = sim_curve['flux_normalized'].values
                sim_time = sim_curve['Days'].values
    
                # if both lenth are equal
                if len(sim_flux) != len(flux):
                    print("❌ light curves are differents.")
                    
                else:
            
        
                    # MSE mean square error
                    mse = np.mean((flux-sim_flux)**2)
        
                    # Extract parameters
                    name_parts = file.replace('.csv', '').split('_')
                    lat = float(name_parts[1].replace('lat', '').replace('-', '-'))
                    lon = float(name_parts[2].replace('lon', ''))
                    rad = float(name_parts[3].replace('rad', ''))
        
                    results.append({
                        'file': file,
                        'lat': lat,
                        'lon': lon,
                        'rad': rad,
                        'mse': mse,
                        'flux': sim_flux
                    })
        
            except Exception as e:
                print(f"Error reading {file}: {e}")
    
    # sorting top 5
    top5 = sorted(results, key=lambda x: x['mse'])[:5]
    
    print("\nTop 5 likely light curve:\n")
    for i, r in enumerate(top5, 1):
        print(f"{i}. Archivo: {r['file']}, Lat: {r['lat']}, Lon: {r['lon']}, Rad: {r['rad']}, MSE: {r['mse']:.10f}")
    
    # plotting LC
    plt.figure(figsize=(12, 8))
    for i, r in enumerate(top5, 1):
        plt.subplot(3, 2, i)
        plt.plot(days, flux, label='lc test', color='black')
        plt.plot(days, r['flux'], label=f"Simulated {i}", linestyle='--')
        plt.title(f"{r['file']} (MSE: {r['mse']:.10f})")
        plt.xlabel("Days")
        plt.ylabel("Flux normalized")
        plt.legend()
    
    plt.tight_layout()
    plt.suptitle("Top 5 MSE light curve", fontsize=16, y=1.02)
    plt.show()

    #return values to be saved in a vector
    return top5[0]["lat"], top5[0]["lon"], top5[0]["rad"]
    



# ---- main ----
if __name__ == '__main__':
    # stellar parameter
    r_val = 1.0
    n_points = 60000
    u1 = 0.4
    u2 =0.3# limb darkening coefficients
    rotation_period = 1.0 * u.day
    
    # Point of view
    elev = 0
    azim = 0
    
    # List of spots
    spots = []
  
    
    # base lines time parameter
    observing_baseline_days = 1 * u.day
    cadence_time = 120 * u.minute
    total_frames = int((observing_baseline_days / cadence_time).decompose().value)
    
    #load flux and days of test light curve
    flux_test, days_test =load_tess()
    #parameters where we are selecting the top1 simulated lightcurve by MSE
    initial_params = function_mse(flux_test, days_test)
# Out:
# Top 5 likely light curve:
#
# 1. Archivo: lc_lat10_lon0_rad10.5.csv, Lat: 10.0, Lon: 0.0, Rad: 10.5, MSE: 0.0000627201
# 2. Archivo: lc_lat-10_lon0_rad10.5.csv, Lat: -10.0, Lon: 0.0, Rad: 10.5, MSE: 0.0000654976
# 3. Archivo: lc_lat30_lon0_rad10.5.csv, Lat: 30.0, Lon: 0.0, Rad: 10.5, MSE: 0.0001612695
# 4. Archivo: lc_lat-30_lon0_rad10.5.csv, Lat: -30.0, Lon: 0.0, Rad: 10.5, MSE: 0.0001655718
# 5. Archivo: lc_lat70_lon60_rad25.5.csv, Lat: 70.0, Lon: 60.0, Rad: 25.5, MSE: 0.0002005678

# %%
#theta_vector =[23,0,12] #test parameters
#flux_simulated,days_simulated =star_animate(theta_vector)
#initial_params

# %%
def inlike(theta_vec,F,days):
    #csv1 = f"{lc1}.csv"
    #csv2 = f"{lc2}.csv"
    
    #df1 = pd.read_csv(csv1)
    #df2 = pd.read_csv(csv2)
    flux_simulated,days_simulated = star_animate(theta_vec)
    #mse = np.mean((df1["flux_normalized"]-df2["flux_normalized"])**2)
    mse = mean_squared_error(F, flux_simulated)
    print(f"📉 MSE entre las curvas: {mse:.15e}")
    #sns.set_theme(style="darkgrid")
# Crear la figura
    #plt.figure(figsize=(10, 6))
    
    # Graficar ambas series
    #sns.lineplot(x=df1["Days"], y=df1["flux_normalized"], label="Test")
    #sns.lineplot(x=df2["Days"], y=df2["flux_normalized"], label="Simulated")
    #sns.lineplot(x=days, y=F, label="Test")
    #sns.lineplot(x=days_simulated, y=flux_simulated, label="Simulated")
    
    # Personalizar
    #plt.title("Light-curve Comparison")
    #plt.xlabel("Days")
    #plt.ylabel("Flux Normalized")
    #plt.ylim(0,1.1)
    #plt.legend()
    
    # Mostrar gráfico
    #plt.show()
    return -mse

# %%
def lnprior(theta_vec):
    #radii = theta_vec
    radii = theta_vec[0]
    if 0.5 <= radii <= 50.0:
        return 0.0
    return -np.inf

# %%
#def lnprob(theta_vec, F, days):
#    lp = lnprior(theta_vec)
#    if not np.isfinite(lp):
#        return -np.inf
#    return lp + lnlike(theta_vec, F,days)
def lnprob(theta_vec, data):
    days, F, Ferr = data
    lp = lnprior(theta_vec)
    if not np.isfinite(lp):
        return -np.inf
    return lp + inlike(theta_vec, F, days)

# %%
flux_err = 0.0005*np.mean(flux_test)
data = (days_test,flux_test,flux_err)
nwalkers = 10
niter = 10
initial = initial_params[2]#np.array(initial_params)

#ndim = len(initial)
ndim = 1
p0 = np.array([initial + 2*np.random.randn() for i in range(nwalkers)])[:, None]

# %%
def main(p0,nwalkers,niter,ndim,lnprob,data):
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(data,))

    print("Running burn-in...")
    p0, _, _ = sampler.run_mcmc(p0, 2)
    sampler.reset()

    print("Running production...")
    pos, prob, state = sampler.run_mcmc(p0, niter)

    return sampler, pos, prob, state

# %%
sampler, pos, prob, state = main(p0,nwalkers,niter,ndim,lnprob,data)
# Out:
# Running burn-in...
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.596381358444232e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.530486821682652e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.946004225147101e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.390965939005346e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.421197513176039e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.092836439220239e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.971040465931986e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.925116518696819e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.004855163283969e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.437097440001030e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.244939315694571e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.707084628464388e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.382358759111801e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.988546728501496e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.046355439961176e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.155787678690280e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.812534705161776e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.401972251129617e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.000146432599613e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.176097685508004e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.798736311397966e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.755852179209616e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.037258437519887e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 7.013524087005431e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.608975452449279e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.326225394317329e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.051048088760039e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.901235636239837e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.764701670635941e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.200156688788290e-05
# Running production...
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.798736311397966e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.326225394317329e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.051048088760039e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.755852179209616e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.901235636239837e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.037258437519887e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 7.013524087005431e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.764701670635941e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.608975452449279e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.200156688788290e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.818235825899738e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.467137855978334e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.305199620878003e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.928805128823342e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.247739174382533e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.987174952702599e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.917830412079848e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.363001657177493e-08
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.270448183086316e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.496767583588650e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.992087270774568e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.948407880393298e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.474077789289655e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.494375771558738e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.933462630485526e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.247737183098252e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.290323234122441e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.764103567524397e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.307928470677954e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.660777877655061e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.864452081868523e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.944397375916563e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.252782724936448e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.569690073641853e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 7.670383014651056e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.916242635025698e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.550504072055829e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.776097841344570e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.335172590452156e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.612344340820746e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 9.504412372797330e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.397027442577237e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.708896328150133e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.038735643838178e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.192240529160193e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.118257007695037e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.916663520990223e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.123870300938331e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.143725381288106e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.569025098559752e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.315206949011663e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 9.360087790160030e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.789480546464274e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.996104866370992e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.519701610366938e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.254484733571907e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.275026450425534e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.439057762128421e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.883315195847915e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.539541334233467e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.042757345635977e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.934515514012095e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.353637429363570e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.453827024725149e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.157793176576810e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.950806585494450e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.117710890205243e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.900594970225578e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.242797356708202e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.668985570206915e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.961161741939004e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.282336901623983e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.011888416868247e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.998763420739040e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.819644810094983e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.289194518934066e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.230728491008780e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.194722908047077e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.283997196621700e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.945200305193442e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.449995162462034e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.338985032684740e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.026235435700534e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.367337010980902e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.488220719877291e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.415785087698982e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.002083249344084e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.056705407268033e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.055467624149828e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.382355178493566e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 6.487324207353956e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.435859607759939e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 9.537424922228853e-05
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 3.286535334256709e-07
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.446472275819386e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 9.131890856506631e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.449293690881836e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 4.790134032943124e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.156214749743101e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.987558668372457e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.158856477319339e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.860488272232922e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.257161665465953e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.578223028527397e-06
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.572561230599895e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 1.382817562042723e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.661307948220476e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 8.662357869509849e-03
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 2.246065440803462e-04
# Generate spherical grid
# start render...
# Generating ligthcurve..
# 📉 MSE entre las curvas: 5.037904624571755e-04

# %%
print("Chain shape:", sampler.chain.shape)
# Out:
# Chain shape: (10, 10, 1)

# %%
samples = sampler.flatchain
samples[np.argmax(sampler.flatlnprobability)]
# Out:
# array([11.97444671])

# %%
def plot_from_csv(csv_files, days=days_test, F=flux_test):
    plt.figure(figsize=(12, 6))
    
    # Curva observada
    plt.plot(days, F, "k.", markersize=4, label="Observed Light Curve")
    
    # Curvas simuladas
    simulated_label_added = False
    for csv_file in csv_files:
        df = pd.read_csv(csv_file)
        if not simulated_label_added:
            plt.plot(df['Days'], df['flux_normalized'], color="r", alpha=0.1, linewidth=0.5, label="Simulated Light Curve")
            simulated_label_added = True
        else:
            plt.plot(df['Days'], df['flux_normalized'], color="r", alpha=0.1, linewidth=0.5)
    
    plt.title("Light Curve from MCMC")
    plt.xlabel("Days", fontsize=12)
    plt.ylabel("Normalized Flux", fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

plot_from_csv(glob.glob("mcmc_light_curves/*.csv"))

# %%
import corner
